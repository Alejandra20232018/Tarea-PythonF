# %%
import numpy as np
import matplotlib.pyplot as plt
import cv2
from PIL import Image

# %% [markdown]
# uno

# %%
img.show()

# %%
def filtrar_color(image,color):
imagen = img.open("image.jpg") 
if color == 1:
    img_image[:,:,0] = 0
elif color == 2:
    img_image[:,:,1] = 0
elif color == 3:
    img_image[:,:,2] = 0
elif color == 10:
    img_image[:,:,2] = 0
elif color == 20:
    img_image[:,:,0] = 0
elif color == 30:
    img_image[:,:,1] = 0

# %% [markdown]
# dos

# %%
def crear_imagen_color(imagen1_gray_azul, imagen1_gray_rojo, imagen1_gray_verde):
img_azul = cv2.imread( imagen_gray_azul, cv2.IMREAD_GRAYSCALE)
img_rojo = cv2.imread( imagen_gray_rojo, cv2.IMREAD_GRAYSCALE)
img_verde = cv2.imread( imagen_gray_verde, cv2.IMREAD_GRAYSCALE)
img_color = cv2.merge((img_azul, img_verde, img_rojo))
cv2.imshow('imagen original', img_color)
cv2.waitkey(0)
cv2.destroyAllWindows()

# %% [markdown]
# cuatro

# %%
strImg="ecualizada.jpg"
img=cv2.imread(strImg, cv2.IMREAD_GRAYSCALE)
img.shape
# Out:
# (214, 704)

# %%
strImg="ecualizada.jpg"
ecualizada=cv2.imread(strImg, cv2.IMREAD_GRAYSCALE)
hist2=cv2.calcHist([ecualizada], [0], None, [256], [0,256])
plt.plot(hist2, color="blue")
plt.xlabel("intensidad de Pixeles")
plt.ylabel("Pixeles Totales 2")
plt.title("Histrograma de Imagen Original 2")
plt.show()

# %% [markdown]
# cinco

# %% [markdown]
# El modelo HSV (del inglés Hue, Saturation, Value – Matiz, Saturación, Valor), también llamado HSB (Hue, Saturation, Brightness – Matiz, Saturación, Brillo), define un modelo de color en términos de sus componentes.
#
# El modelo de color HSV se basa en un sistema de color en el que el espacio de color se representa mediante un único cono: tono, saturación y valor. La función Conversión de modelo de color se puede utilizar en un dataset de mosaico. Esta función solo admite entradas de 3 bandas.
